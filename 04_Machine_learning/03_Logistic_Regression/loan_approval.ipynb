# %% [markdown]
# ## Loan Approval Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("loan_approval_dataset.csv")
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
print(df[" education"].unique())
# Out:
# <StringArray>
# [' Graduate', ' Not Graduate']
# Length: 2, dtype: str

# %%
df.corr(numeric_only=True)
# Out:
#                             loan_id   no_of_dependents   income_annum  \
# loan_id                    1.000000           0.005326       0.012592
#  no_of_dependents          0.005326           1.000000       0.007266
#  income_annum              0.012592           0.007266       1.000000
#  loan_amount               0.008170          -0.003366       0.927470
#  loan_term                 0.009809          -0.020111       0.011488
#  cibil_score               0.016323          -0.009998      -0.023034
#  residential_assets_value  0.020936           0.007376       0.636841
#  commercial_assets_value   0.018595          -0.001531       0.640328
#  luxury_assets_value      -0.000862           0.002817       0.929145
#  bank_asset_value          0.010765           0.011163       0.851093
#
#                             loan_amount   loan_term   cibil_score  \
# loan_id                        0.008170    0.009809      0.016323
# ...

# %%
## space before education column is causing issue while encoding. So, we will remove the space before education column and then encode it.
df.columns = df.columns.str.strip()

# %%
print(df["education"].unique())
# Out:
# <StringArray>
# [' Graduate', ' Not Graduate']
# Length: 2, dtype: str

# %%
## Encode education column without encoder 
df["education"] = df["education"].str.strip()  # Remove any leading/trailing spaces
df["education"] = df["education"].map({"Not Graduate": 0, "Graduate": 1})

# %%
df.head()
# Out:
#    loan_id  no_of_dependents  education self_employed  income_annum  \
# 0        1                 2          1            No       9600000
# 1        2                 0          0           Yes       4100000
# 2        3                 3          1            No       9100000
# 3        4                 3          1            No       8200000
# 4        5                 5          0           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17600000             22700000           8000000    Approved
# ...

# %%
## encode self_employed column without encoder
df["self_employed"] = df["self_employed"].str.strip()  # remove trailing spaces
df["self_employed"] = df["self_employed"].map({"No": 0, "Yes": 1})

# %%
df.head()
# Out:
#    loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0        1                 2          1              0       9600000
# 1        2                 0          0              1       4100000
# 2        3                 3          1              0       9100000
# 3        4                 3          1              0       8200000
# 4        5                 5          0              1       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17600000             22700000           8000000    Approved
# ...

# %%
## encode loan_status column without encoder
df["loan_status"] = df["loan_status"].str.strip()  # remove trailing spaces
df["loan_status"] = df["loan_status"].map({"Rejected": 0, "Approved": 1})

# %%
df.head()
# Out:
#    loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0        1                 2          1              0       9600000
# 1        2                 0          0              1       4100000
# 2        3                 3          1              0       9100000
# 3        4                 3          1              0       8200000
# 4        5                 5          0              1       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value  loan_status
# 0                 17600000             22700000           8000000            1
# ...

# %%
df.corr()
# Out:
#                            loan_id  no_of_dependents  education  \
# loan_id                   1.000000          0.005326   0.015536
# no_of_dependents          0.005326          1.000000   0.002697
# education                 0.015536          0.002697   1.000000
# self_employed             0.001745          0.000765  -0.023224
# income_annum              0.012592          0.007266   0.011625
# loan_amount               0.008170         -0.003366   0.010631
# loan_term                 0.009809         -0.020111  -0.008417
# cibil_score               0.016323         -0.009998  -0.004649
# residential_assets_value  0.020936          0.007376   0.010930
# commercial_assets_value   0.018595         -0.001531  -0.006763
# luxury_assets_value      -0.000862          0.002817   0.012471
# bank_asset_value          0.010765          0.011163   0.009424
# loan_status               0.017685         -0.018114   0.004918
#
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# heatmap to visualize correlation between features
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# ## Feature selection

# %%
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='str')

# %%
X = df.drop(columns=["loan_status", "loan_id"])
Y = df["loan_status"]

# %%
X
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              0       9600000     29900000
# 1                    0          0              1       4100000     12200000
# 2                    3          1              0       9100000     29700000
# 3                    3          1              0       8200000     30700000
# 4                    5          0              1       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              1       1000000      2300000
# 4265                 0          0              1       3300000     11300000
# 4266                 2          0              0       6500000     23900000
# 4267                 1          0              0       4100000     12800000
# 4268                 1          1              0       9200000     29700000
#
# ...

# %%
Y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4264    0
# 4265    1
# 4266    0
# 4267    1
# 4268    1
# Name: loan_status, Length: 4269, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=42,test_size=0.25,stratify=Y)

# %%
X.shape
# Out:
# (4269, 11)

# %%
X_train.shape,X_test.shape
# Out:
# ((3201, 11), (1068, 11))

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   int64
#  3   self_employed             4269 non-null   int64
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   int64
# dtypes: int64(13)
# memory usage: 433.7 KB

# %%
# Standardlization of data using StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
## Model Building
from sklearn.linear_model import LogisticRegression
logistic = LogisticRegression()
logistic.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logistic.predict(X_test)

# %%
## Performance metrics 
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print(classification_report(y_pred,Y_test))
print(confusion_matrix(y_pred,Y_test))
print(accuracy_score(y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       393
#            1       0.94      0.93      0.94       675
#
#     accuracy                           0.92      1068
#    macro avg       0.91      0.92      0.91      1068
# weighted avg       0.92      0.92      0.92      1068
#
# [[355  38]
#  [ 49 626]]
# 0.9185393258426966

# %%
# prediction for new data
new_data = [[30, 50000, 2, 1]]  # Example new data point
new_data = [[0, 0, 0, 9600000, 29900000, 10, 118, 200000, 1600000, 20000, 70000]]
new_data_scaled = scaler.transform(new_data)
prediction = logistic.predict(new_data_scaled)
print(f"Prediction for new data: {prediction[0]}")
# Out:
# Prediction for new data: 1

# %%
## Save the model using pickle
import pickle 
pickle.dump(logistic,open('loan_approval_prediction_model.pkl','wb'))
pickle.dump(scaler,open('loan_approval_prediction_ scaler.pkl','wb'))
