# %% [markdown]
# ## EDA and Data Cleaning on Algerian_forest_fires_dataset.csv

# %%
import numpy as np 
import pandas as pd
import matplotlib as plt 
import seaborn as sns

# %%
df = pd.read_csv('Algerian_forest_fires_dataset.csv',header=1)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature,  RH,  Ws, Rain , FFMC, DMC, DC, ISI, BUI, FWI, Classes  ]
# Index: []

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.shape
# Out:
# (246, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
# dtypes: str(14)
# memory usage: 27.0 KB

# %% [markdown]
# ## Data Cleaning

# %%
df[df.isnull().any(axis=1)]
# Sidi bel region
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc[:122,"Region"]=0 
df.loc[122:,"Region"]=1

# sidibel region = 0
# begial region = 1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
#  14  Region       246 non-null    float64
# dtypes: float64(1), str(14)
# memory usage: 29.0 KB

# %%
df[["Region"]]=df[["Region"]].astype(int)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 241  6.5       fire          1
# 242    0   not fire          1
# 243  0.2   not fire          1
# 244  0.7   not fire          1
# 245  0.5  not fire           1

# %%
df.info()
# Region become int
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
#  14  Region       246 non-null    int64
# dtypes: int64(1), str(14)
# memory usage: 29.0 KB

# %%
df.isnull().sum() #Total null value
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df=df.dropna().reset_index(drop=True) # Dropping null values 
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum() # null values removed
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]] # should drop this row
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df=df.drop(122).reset_index(drop=True) #Dropped the 122nd row

# %%
df.columns
#There ae spaces in column names like space after Classes
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='str')

# %%
## Fix spaces in columns names
df.columns = df.columns.str.strip() #strip() method remove widespaces 
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    str
#  1   month        243 non-null    str
#  2   year         243 non-null    str
#  3   Temperature  243 non-null    str
#  4   RH           243 non-null    str
#  5   Ws           243 non-null    str
#  6   Rain         243 non-null    str
#  7   FFMC         243 non-null    str
#  8   DMC          243 non-null    str
#  9   DC           243 non-null    str
#  10  ISI          243 non-null    str
#  11  BUI          243 non-null    str
#  12  FWI          243 non-null    str
#  13  Classes      243 non-null    str
#  14  Region       243 non-null    int64
# dtypes: int64(1), str(14)
# memory usage: 28.6 KB

# %% [markdown]
# ### Change the required columns as integer data type

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='str')

# %%
df[['month','day','year','Temperature','RH','Ws']]= df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    str
#  7   FFMC         243 non-null    str
#  8   DMC          243 non-null    str
#  9   DC           243 non-null    str
#  10  ISI          243 non-null    str
#  11  BUI          243 non-null    str
#  12  FWI          243 non-null    str
#  13  Classes      243 non-null    str
#  14  Region       243 non-null    int64
# dtypes: int64(7), str(8)
# memory usage: 28.6 KB

# %% [markdown]
# ### Changing the other columns to float data types

# %%
str=[features for features in df.columns if df[features].dtypes=='str']

# %%
for i in str:
    if i!= 'Classes' :
     df[i]=df[i].astype(float)

# %%
df[["Classes"]] = df[["Classes"]].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %% [markdown]
# ### Lets save the cleaned Dataset

# %%
df.to_csv('Algerian_forest_fire_cleaned_dataset.csv',index = False)

# %% [markdown]
# ### Exploratory Data Analysis on Cleaned Dataset

# %%
df["New_Column"] = df["Rain"] + df["RH"] + df["Ws"]

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region  New_Column
# 0  0.5  not fire          0        75.0
# 1  0.4  not fire          0        75.3
# 2  0.1  not fire          0       117.1
# 3  0.0  not fire          0       104.5
# 4  0.5  not fire          0        93.0

# %%
df_copy= df

# %%
df_copy.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region  New_Column
# 0  0.5  not fire          0        75.0
# 1  0.4  not fire          0        75.3
# 2  0.1  not fire          0       117.1
# 3  0.0  not fire          0       104.5
# 4  0.5  not fire          0        93.0

# %%
# Dropping day and month columns 
df_copy = df.drop(['day','month'],axis=1)

# %%
df_copy.head()
# Out:
#    year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5
#
#        Classes  Region  New_Column
# 0  not fire          0        75.0
# 1  not fire          0        75.3
# 2  not fire          0       117.1
# 3  not fire          0       104.5
# 4  not fire          0        93.0

# %%
## Encoding of the categories in classes 
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'), 0, 1)

# %%
df_copy.head()
# Out:
#    year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  \
# 0  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0
#
#    Region  New_Column
# 0       0        75.0
# 1       0        75.3
# 2       0       117.1
# 3       0       104.5
# 4       0        93.0

# %%
df_copy.tail()
# Out:
#      year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 238  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#      Classes  Region  New_Column
# 238        1       1        79.0
# 239        0       1       106.4
# 240        0       1       116.5
# 241        0       1        72.1
# 242        0       1        79.2

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

## Plot density plot for all features
## Plot density plot for all features
sns.set_theme(style='darkgrid')
df_copy.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'Temperature'}>,
#         <Axes: title={'center': 'RH'}>, <Axes: title={'center': 'Ws'}>],
#        [<Axes: title={'center': 'Rain'}>,
#         <Axes: title={'center': 'FFMC'}>,
#         <Axes: title={'center': 'DMC'}>, <Axes: title={'center': 'DC'}>],
#        [<Axes: title={'center': 'ISI'}>, <Axes: title={'center': 'BUI'}>,
#         <Axes: title={'center': 'FWI'}>,
#         <Axes: title={'center': 'Classes'}>],
#        [<Axes: title={'center': 'Region'}>,
#         <Axes: title={'center': 'New_Column'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
## Percentage of Pie Chart
df_copy['Classes'].value_counts(normalize=True)*100
# Out:
# Classes
# 1    56.378601
# 0    43.621399
# Name: proportion, dtype: float64

# %%
## Plotting Pie Chart
classlabels = ["Fire","Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage, labels=classlabels, autopct='%1.1f%%')
plt.title('Pie Chart')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 4
#       1 ## Plotting Pie Chart
#       2 classlabels = ["Fire","Not Fire"]
#       3 plt.figure(figsize=(12,7))
# ----> 4 plt.pie(percentage, labels=classlabels, autopct='%1.1f%%')
#       5 plt.title('Pie Chart')
#       6 plt.show()
#
# NameError: name 'percentage' is not defined

# %%
## Correlation
df_copy.corr()
# Out:
#              year  Temperature        RH        Ws      Rain      FFMC  \
# year          NaN          NaN       NaN       NaN       NaN       NaN
# Temperature   NaN     1.000000 -0.651400 -0.284510 -0.326492  0.676568
# RH            NaN    -0.651400  1.000000  0.244048  0.222356 -0.644873
# Ws            NaN    -0.284510  0.244048  1.000000  0.171506 -0.166548
# Rain          NaN    -0.326492  0.222356  0.171506  1.000000 -0.543906
# FFMC          NaN     0.676568 -0.644873 -0.166548 -0.543906  1.000000
# DMC           NaN     0.485687 -0.408519 -0.000721 -0.288773  0.603608
# DC            NaN     0.376284 -0.226941  0.079135 -0.298023  0.507397
# ISI           NaN     0.603871 -0.686667  0.008532 -0.347484  0.740007
# BUI           NaN     0.459789 -0.353841  0.031438 -0.299852  0.592011
# FWI           NaN     0.566670 -0.580957  0.032368 -0.324422  0.691132
# Classes       NaN     0.516015 -0.432161 -0.069964 -0.379097  0.769492
# ...

# %%
sns.heatmap(df_copy.corr())
# Out:
# <Axes: >

# %%
## Box plot 
sns.boxplot(df['FWI'],color='green')
# Out:
# <Axes: ylabel='FWI'>

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df_copy.head()
# Out:
#    year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  \
# 0  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
## Monthly Fire analysis (Bejaia Region == 0)
df['Classes'] = np.where(df['Classes'].str.contains('not fire'), 'not fire', 'fire')
dftemp = df.loc[df['Region']==0]
plt.subplots(figsize=(13,6)),
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('Number of fires',weight = 'bold')
plt.xlabel('Months',weight='bold')
plt.title('Fire analysis of bejaia region',weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire analysis of bejaia region')

# %%
## Monthly Fire analysis (Sidi bel Region == 1)
df['Classes'] = np.where(df['Classes'].str.contains('not fire'), 'not fire', 'fire')
dftemp = df.loc[df['Region']==1]
plt.subplots(figsize=(13,6)),
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('Number of fires',weight = 'bold')
plt.xlabel('Months',weight='bold')
plt.title('Fire analysis of Sidi bel region',weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire analysis of Sidi bel region')

# %% [markdown]
# - It is observed that the most number of forest fires in both the regions are in august and september.
# - most fires happened in august
# - and very high fires happend iin 3 months june july and august
# - very less fires in september
