# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### one independent or input feature
# #### one dependent or output feature

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("simple_linear_dataset.csv")
df.head()
# Out:
#    Height_cm  Weight_kg
# 0        150         45
# 1        151         49
# 2        152         54
# 3        153         44
# 4        154         40

# %%
 ## scatter plot 
plt.scatter(df['Weight_kg'],df['Height_cm'])
plt.xlabel("Weight_kg")
plt.ylabel("Height_cm")
# Out:
# Text(0, 0.5, 'Height_cm')

# %%
##Correlation
df.corr()
# Out:
#            Height_cm  Weight_kg
# Height_cm   1.000000   0.776025
# Weight_kg   0.776025   1.000000

# %%
## Seaborn for visualization
import seaborn as sns
sns.pairplot(df)

# %%
## Independent features
X = df['Weight_kg']
type(X) # it is a series 
# type(df) it is a dataframe
# Out:
# pandas.Series

# %%
X = df[['Weight_kg']]
type(X) # will be dataframe 
# always  independent feature should be dataframe or 2d array not a series
# Out:
# pandas.DataFrame

# %%
# Dependent feature
Y = df['Height_cm'] # This variable can be in series for or 1d array
Y
# Out:
# 0     150
# 1     151
# 2     152
# 3     153
# 4     154
# 5     155
# 6     156
# 7     157
# 8     158
# 9     159
# 10    169
# 11    161
# 12    149
# 13    163
# 14    164
# 15    165
# 16    166
# 17    167
# 18    168
# 19    169
# 20    170
# 21    185
# 22    172
# 23    173
# 24    174
# 25    175
# 26    176
# 27    177
# 28    178
# 29    179
# 30    180
# 31    181
# 32    182
# 33    183
# 34    184
# Name: Height_cm, dtype: int64

# %%
## Train Test Split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (26, 1)
