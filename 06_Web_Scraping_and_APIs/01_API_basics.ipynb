# %% [markdown]
# ## API

# %% [markdown]
# # API (Application Programming Interface)
#
# ## Definition
# An *API (Application Programming Interface)* is a set of rules that allows two software applications to communicate with each other and exchange data.
#
# Think of an API as a *messenger* between the client and the server.
#
# ---
#
# ## Real-World Example (Train Ticket Booking)
#
# Suppose we want to book a train ticket.
#
# There are multiple platforms:
#
# - IRCTC
# - MakeMyTrip
# - Yatra.com
#
# Imagine someone books Seat *B142* on the *Agra Express* through the IRCTC website.
#
# Now, if another user searches for the same seat on MakeMyTrip or Yatra, the seat should immediately appear as *Booked* or *Not Available*.
#
# This synchronization happens through *APIs*.
#
# Each website has its own application and database, but they communicate using APIs to exchange information.
#
# ---
#
# ## Important Concept
#
# Different websites may have different databases.
#
# MakeMyTrip does *not* directly access IRCTC's database.
#
# Instead:
#
# 1. MakeMyTrip sends an API request.
# 2. The IRCTC server processes the request.
# 3. IRCTC checks its database.
# 4. The server returns the required information.
# 5. MakeMyTrip displays the updated result to the user.
#
# ---
#
# ## API Flow
#
#
# Python Application / Website
#             │
#             ▼
#        API Request
#             │
#             ▼
#          Server
#             │
#             ▼
#         Database
#             │
#             ▼
#       API Response (JSON)
#             │
#             ▼
# Python Application / Website
#
#
# ---
#
# ## API Does NOT Directly Access the Database
#
# An API itself does *not* access the database.
#
# The application sends a request to the server.
#
# The server may:
# - Read data from the database
# - Process the request
# - Perform authentication
# - Apply business logic
# - Return the response
#
# ---
#
# ## API Returns Data
#
# Most APIs return data in *JSON (JavaScript Object Notation)* format.
#
# Example:
#
# json
# {
#     "train": "Agra Express",
#     "seat": "B142",
#     "status": "Booked"
# }
#
#
# ---
#
# ## Why APIs are Used
#
# - Communication between applications
# - Share data securely
# - Access real-time information
# - Integrate third-party services
# - Build scalable applications
#
# ---
#
# ## Common Uses of APIs in Data Science
#
# - Download datasets
# - Weather data
# - Stock market data
# - Cryptocurrency prices
# - News data
# - Sports statistics
# - Social media data
# - Google Maps
# - OpenAI APIs
# - Hugging Face APIs
#
# ---
#
# ## Important Terms
#
# - Client
# - Server
# - Request
# - Response
# - Endpoint
# - JSON
# - API Key
# - Authentication
# - HTTP Methods (GET, POST, PUT, DELETE)
#
# ---
#
# ## Summary
#
# An API is a communication bridge between two applications.
#
# It follows predefined rules for exchanging data.
#
# Applications do not directly communicate with databases; they communicate with servers through APIs, and servers return the required information.

# %%
import http.client

conn = http.client.HTTPSConnection("covid-19-statistics.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "a24a1c8781mshb58fff0089f37d8p127d26jsnbbad3f2855d9",
    'x-rapidapi-host': "covid-19-statistics.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("GET", "/provinces?iso=CHN", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"data":[{"iso":"CHN","name":"China","province":"Anhui","lat":"31.8257","long":"117.2264"},{"iso":"CHN","name":"China","province":"Beijing","lat":"40.1824","long":"116.4142"},{"iso":"CHN","name":"China","province":"Chongqing","lat":"30.0572","long":"107.8740"},{"iso":"CHN","name":"China","province":"Fujian","lat":"26.0789","long":"117.9874"},{"iso":"CHN","name":"China","province":"Gansu","lat":"36.0611","long":"103.8343"},{"iso":"CHN","name":"China","province":"Guangdong","lat":"23.3417","long":"113.4244"},{"iso":"CHN","name":"China","province":"Guangxi","lat":"23.8298","long":"108.7881"},{"iso":"CHN","name":"China","province":"Guizhou","lat":"26.8154","long":"106.8748"},{"iso":"CHN","name":"China","province":"Hainan","lat":"19.1959","long":"109.7453"},{"iso":"CHN","name":"China","province":"Hebei","lat":"38.0428","long":"114.5149"},{"iso":"CHN","name":"China","province":"Heilongjiang","lat":"47.8620","long":"127.7615"},{"iso":"CHN","name":"China","province":"Henan","lat":"33.8820","
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("covid-19-statistics.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "a24a1c8781mshb58fff0089f37d8p127d26jsnbbad3f2855d9",
    'x-rapidapi-host': "covid-19-statistics.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("GET", "/regions", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"data":[{"iso":"CHN","name":"China"},{"iso":"TWN","name":"Taipei and environs"},{"iso":"USA","name":"US"},{"iso":"JPN","name":"Japan"},{"iso":"THA","name":"Thailand"},{"iso":"KOR","name":"Korea, South"},{"iso":"SGP","name":"Singapore"},{"iso":"PHL","name":"Philippines"},{"iso":"MYS","name":"Malaysia"},{"iso":"VNM","name":"Vietnam"},{"iso":"AUS","name":"Australia"},{"iso":"MEX","name":"Mexico"},{"iso":"BRA","name":"Brazil"},{"iso":"COL","name":"Colombia"},{"iso":"FRA","name":"France"},{"iso":"NPL","name":"Nepal"},{"iso":"CAN","name":"Canada"},{"iso":"KHM","name":"Cambodia"},{"iso":"LKA","name":"Sri Lanka"},{"iso":"CIV","name":"Cote d'Ivoire"},{"iso":"DEU","name":"Germany"},{"iso":"FIN","name":"Finland"},{"iso":"ARE","name":"United Arab Emirates"},{"iso":"IND","name":"India"},{"iso":"ITA","name":"Italy"},{"iso":"GBR","name":"United Kingdom"},{"iso":"RUS","name":"Russia"},{"iso":"SWE","name":"Sweden"},{"iso":"ESP","name":"Spain"},{"iso":"BEL","name":"Belgium"},{"iso":"Others","name":"O
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("covid-19-statistics.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "a24a1c8781mshb58fff0089f37d8p127d26jsnbbad3f2855d9",
    'x-rapidapi-host': "covid-19-statistics.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("GET", "/reports?city_name=Autauga&region_province=Alabama&iso=USA&region_name=US&q=US%20Alabama&date=2020-04-16", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"data":[{"date":"2020-04-16","confirmed":4345,"deaths":133,"recovered":0,"confirmed_diff":270,"deaths_diff":15,"recovered_diff":0,"last_update":"2020-04-16 23:30:51","active":4212,"active_diff":255,"fatality_rate":0.0306,"region":{"iso":"USA","name":"US","province":"Alabama","lat":"32.3182","long":"-86.9023","cities":[{"name":"Autauga","date":"2020-04-16","fips":1001,"lat":"32.53952745","long":"-86.64408227","confirmed":26,"deaths":1,"confirmed_diff":2,"deaths_diff":0,"last_update":"2020-04-16 23:30:51"}]}}]}
